# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from spacy import displacy
from scipy.stats.stats import pearsonr

# %% [markdown]
# #### Aula 1 - Análise abstracts

# %%
arqs = os.listdir('../dados')

# %%
for i,arq in enumerate(arqs):
    
    if i == 0:
        # df = pd.read_excel(f'C:/JupyterLab/PCA/Aula 02/praticas-computacionais-avancadas/dados/{arq}')
        df = pd.read_excel(f'../dados/{arq}')
    else:
        # aux = pd.read_excel(f'C:/JupyterLab/PCA/Aula 02/praticas-computacionais-avancadas/dados/{arq}')
        aux = pd.read_excel(f'../dados/{arq}')
        df = pd.concat([df,aux])

# %%
plt.hist(df['Language'], color='purple')
plt.title('Idiomas')
plt.show()

# %%
for i,arq in enumerate(arqs):
    
    if i == 0:
        df = pd.read_excel(f'../dados/{arq}')
        df = df.loc[df['Language'] == 'English']
    else:
        aux = pd.read_excel(f'../dados/{arq}')
        aux = aux.loc[aux['Language'] == 'English']
        df = pd.concat([df,aux])

# %%
plt.hist(df['Number of Pages'], color='purple')
plt.title('Número de Páginas')
plt.show()

# %%
plt.hist(df['Cited Reference Count'], color='purple')
plt.title('Contagem de referências')
plt.show()

# %%
plt.hist(df['Publication Year'], color='purple')
plt.title('Ano de publicação')
plt.show()

# %%
qtd = 11
plt.hist(df['Research Areas'][:qtd], color='purple')
plt.title('Áreas de pesquisa')
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(df['Funding Orgs'].astype(str)[:qtd], color='purple')
plt.title('Orgão financiadores')
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(df['Publisher'][:qtd], color='purple')
plt.title('Editora')
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(df['Journal Abbreviation'].astype(str)[:qtd], color='purple')
plt.title('Journal (abreviação)')
plt.xticks(rotation=45)
plt.show()

# %%
dic_key={}

for keywords in df['Keywords Plus']:
    if not isinstance(keywords,float):
        
        keywords = keywords.split(' ')
        
        for keyword in keywords:
            if ';' in keyword:
                keyword = keyword.replace(';','')
            
            keyword = keyword.lower()
            
            if keyword not in dic_key:
                dic_key[keyword] = 1
            else:
                dic_key[keyword] += 1

dic_key = dict(sorted(dic_key.items(), key=lambda item: item[1]))

# %%
qtd = 10
plt.barh(list(dic_key.keys())[-qtd:],list(dic_key.values())[-qtd:],color='purple')
plt.title(f'{qtd} palavras mais recorrentes nas keywords')
plt.show()

# %% [markdown]
# #### Aula 2 - Extração dos valores em ms

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
limite = 20
count = 0
lista_vals, abs_vals = [], []

for abs_index,abstract in enumerate(df['Abstract']):

    if not isinstance(abstract,float):
        if ' ms ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            ms_indexes = []
            for t in doc:
                if t.text=='ms':
                    ms_indexes.append(t.i)
                    count+=1
                    
            for ms_index in ms_indexes:
                doc_aux = doc[ms_index-20:ms_index+20]
                doc_aux = nlp(str(doc_aux))
                
                #print(doc_aux)
                for t in doc_aux:
                    if t.text=='ms':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_vals.append(vals[::-1])
                            abs_vals.append([abs_index,vals[::-1],doc_aux])      
        
        if ' millisecond ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            ms_indexes = []
            for t in doc:
                if t.text=='millisecond':
                    ms_indexes.append(t.i)
                    count+=1
                    
            for ms_index in ms_indexes:
                doc_aux = doc[ms_index-20:ms_index+20]
                doc_aux = nlp(str(doc_aux))
                
                # print(doc_aux)
                for t in doc_aux:
                    if t.text=='millisecond':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_vals.append(vals[::-1])
                            abs_vals.append([abs_index,vals[::-1],doc_aux])
        
        if ' milliseconds ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            ms_indexes = []
            for t in doc:
                if t.text=='milliseconds':
                    ms_indexes.append(t.i)
                    count+=1
                    
            for ms_index in ms_indexes:
                doc_aux = doc[ms_index-20:ms_index+20]
                doc_aux = nlp(str(doc_aux))
                
                # print(doc_aux)
                for t in doc_aux:
                    if t.text=='milliseconds':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_vals.append(vals[::-1])
                            abs_vals.append([abs_index,vals[::-1],doc_aux])

# %%
abs_vals
# Out:
# [[10,
#   ['hundred'],
#   amplitude of about 100 mV. However, differently from the nerve cell, the action potential lasts a few hundred milliseconds before repolarization. Moreover, several types of K+ channel such as the classical inward rectifier K+ channel,],
#  [25,
#   ['100', '-', '120'],
#   . In seven of ten type B cells tested, the spontaneous spikes developed plateau potentials of 100-120 ms duration in 10 mM TEA, which then became 7-9 s long in Ca2+-free medium],
#  [25,
#   ['to', '30', '-', '100'],
#   , the spontaneous plateaux were 1.75-2 s long in TEA, and were reduced to 30-100 ms in Ca2+-free medium. TTX abolished the spontaneous spikes and plateaux. The delayed AHP was abolished],
#  [28,
#   ['100'],
#   strength-duration time constant (tau(SD)); current/threshold relationship; threshold electrotonus to a 100 ms polarizing current; and recovery curves to a supramaximal stimulus. Results: Compound muscle action potential (CMAP],
#  [28,
#   ['0.50', '+', '/-', '0.03'],
#   with membrane hyperpolarization. The tau(SD) was significantly increased in ALS patients (ALS, 0.50 +/- 0.03 ms; controls, 0.42 +/- 0.02 ms, P < 0.05). The recovery cycle of excitability],
#  [28,
#   ['0.42', '+', '/-', '0.02'],
#   with membrane hyperpolarization. The tau(SD) was significantly increased in ALS patients (ALS, 0.50 +/- 0.03 ms; controls, 0.42 +/- 0.02 ms, P < 0.05). The recovery cycle of excitability],
#  [28,
#   ['0.50', '+', '/-', '0.03'],
#   significantly increased in ALS patients (ALS, 0.50 +/- 0.03 ms; controls, 0.42 +/- 0.02 ms, P < 0.05). The recovery cycle of excitability following a conditioning supramaximal stimulus revealed increased superexcitability],
#  [28,
#   ['0.42', '+', '/-', '0.02'],
#   significantly increased in ALS patients (ALS, 0.50 +/- 0.03 ms; controls, 0.42 +/- 0.02 ms, P < 0.05). The recovery cycle of excitability following a conditioning supramaximal stimulus revealed increased superexcitability],
#  [44,
#   ['9.8', '+', '/-', '4.5'],
#   /- 10.9 M Omega) and longer membrane time constants (18.6 +/- 8.1 vs. 9.8 +/- 4.5 ms) than basket cells. Differences were also apparent in the duration of action potentials, those of basket],
#  [44,
#   ['1.9', '+', '/-', '0.5', 'and', '10.7', '+', '/-', '5.6'],
#   half-amplitude) of subthreshold EPSPs in basket cells were 1.9 +/- 0.5 and 10.7 +/- 5.6 ms, compared to 3.3 +/- 1.3 and 20.1 +/- 9.7 ms in bistratified cells, the difference],
#  [44,
#   ['to', '3.3', '+', '/-', '1.3', 'and', '20.1', '+', '/-', '9.7'],
#   half-amplitude) of subthreshold EPSPs in basket cells were 1.9 +/- 0.5 and 10.7 +/- 5.6 ms, compared to 3.3 +/- 1.3 and 20.1 +/- 9.7 ms in bistratified cells, the difference],
#  [44,
#   ['/-', '0.5', 'and', '10.7', '+', '/-', '5.6'],
#   /- 0.5 and 10.7 +/- 5.6 ms, compared to 3.3 +/- 1.3 and 20.1 +/- 9.7 ms in bistratified cells, the difference in EPSP rise times being statistically significant. Basket and bistratified EPSPs were],
#  [44,
#   ['to', '3.3', '+', '/-', '1.3', 'and', '20.1', '+', '/-', '9.7'],
#   /- 0.5 and 10.7 +/- 5.6 ms, compared to 3.3 +/- 1.3 and 20.1 +/- 9.7 ms in bistratified cells, the difference in EPSP rise times being statistically significant. Basket and bistratified EPSPs were],
#  [45,
#   ['25'],
#   burst duration-dependent manner with E(c) as low as 16 V/cm (4000 Hz, 25 ms burst). There was no evidence of electroporation at field intensities near the E(c) for nociceptor activation],
#  [51,
#   ['150'],
#   . However, CV was markedly reduced in both treated and untreated TAC hearts throughout dynamic pacing. At 150 ms pacing cycle length, APD(60) versus diastolic interval dispersion was reduced in treated hearts compared with untreated hearts],
#  [53,
#   ['zero'],
#   the direction of the conduction delay for the primary population spike, but typically was less, and approached zero milliseconds for some cycles in most cells. The level of synchrony was stable for particular stimulating conditions (intensity],
#  [55,
#   ['10'],
#   spike exceeded 90% if that S-potential was preceded by an S-potential within the previous 10 ms (100 Hz). Whereas this temporal influence on efficacy has been demonstrated extensively in anesthetized animals,],
#  [62,
#   ['3'],
#   0.0001) and decreased short interval intracortical inhibition (SICI) (p < 0.001). SICI at 3 ms (p < 0.05, beta = -0.21) and averaged SICI (p < 0.05, beta =],
#  [62,
#   ['3'],
#   p < 0.01, beta = 0.25), while ALSFRS-R decline correlated with decreased SICI at 3 ms (p < 0.01, beta = 0.20). Conclusions: Clinical measures combined with assessment of cortical],
#  [85,
#   ['0.1'],
#   prescribed anticonvulsant therapy, and 15 control subjects. Results: Rheobase of motor fibres and stimulus strength at 0.1 ms and 1ms of motor fibres of total patients with epilepsy were higher than values of controls. Conclusions:],
#  [97,
#   ['0.57'],
#   was modeled as the difference between two exponentials. A fast time constant (tau(2); mean value 0.57 ms), which proves to be virtually voltage-independent, governs the current rise phase and a longer],
#  [97,
#   ['5.2', '-', '6.8'],
#   independent, governs the current rise phase and a longer time constant (tau(1); range 5.2-6.8 ms in 2 mM Ca2+) describes the current decay and shows a small negative voltage dependence. A],
#  [97,
#   ['1'],
#   shown that under appropriate conditions the duration of the driving function describing quantal secretion can be reduced to < 1 ms. The shape of the EPSC is accurately mimicked by a complete mathematical model of the sympathetic neuron incorporating],
#  [103,
#   ['250', '500'],
#   conditions favoring Ca2+ release. The window, measured from the end of the train, lasted 250 500 ms depending on the duration of stimulation tetanus. The window appears to correspond to the time when both IP3],
#  [108,
#   ['1'],
#   with FluoVolt dye. Electroporation abruptly shifted OMP to a more depolarized level, which was reached within <1 ms. The OMP recovery started rapidly (T = 8-12 ms) but gradually slowed down (],
#  [108,
#   ['8', '-', '12'],
#   with FluoVolt dye. Electroporation abruptly shifted OMP to a more depolarized level, which was reached within <1 ms. The OMP recovery started rapidly (T = 8-12 ms) but gradually slowed down (],
#  [108,
#   ['1'],
#   , which was reached within <1 ms. The OMP recovery started rapidly (T = 8-12 ms) but gradually slowed down (to T> 10 s), so cells remained above the resting],
#  [108,
#   ['8', '-', '12'],
#   , which was reached within <1 ms. The OMP recovery started rapidly (T = 8-12 ms) but gradually slowed down (to T> 10 s), so cells remained above the resting],
#  [108,
#   ['4', '-', '5'],
#   enhanced the depolarizing effect of electroporation, resulting in an additional tetrodotoxin-sensitive OMP peak in 4-5 ms after nsPEF. Omitting Ca2+ in the extracellular solution did not reduce the depolarization, suggesting no contribution],
#  [108,
#   ['0.5'],
#   the electroporation threshold (1.5-1.9 kV/cm). VGSC opening could already be detected in 0.5 ms after nsPEF, which is too fast to be mediated by the depolarizing effect of electroporation. The overlap],
#  [113,
#   ['to', '1'],
#   The time constant for activation of this current decreased with membrane depolarization to a minimum value of similar to 1 ms. The 4-AP-sensitive current showed steady-state inactivation with a half-inactivation of],
#  [113,
#   ['8.5', '+', '/-', '0.7'],
#   of approximately -70 mV. A second, more slowly activating current (activation time constant was 8.5 +/- 0.7 ms at -8 mV) was sensitive to TEA (30 mM). The TEA-sensitive current also],
#  [113,
#   ['500', '-'],
#   showed steady-state inactivation with a half-inactivation of -95.4 +/- 1.4 mV, following 500-ms duration conditioning pulses. A combination of 4-AP and TEA blocked similar to 90% of the],
#  [114,
#   ['40', '+', '17.6'],
#   an average input resistance of 226 +/- 100 M Omega. The membrane time constant was 40 + 17.6 ms and the action potential threshold was -51.6 +/- 3 mV. 3. Injections of hyperpolarizing current pulses from],
#  [124,
#   ['100'],
#   rhythmic activity is enhanced by serotonin. The interneurons 7 and 8 produce one prolonged action potential (about 100 ms in duration) per cycle. Prolonged action potentials contribute to determining the duration of the cycle phases.],
#  [126,
#   ['67.8', '+', '/-', '6.3'],
#   receptor agonists. The mean duration of the sAHPs (+/-SEM) in control was 67.8 +/- 6.3 ms whereas in the presence of SP and [Sar(9)Met(O-2)(11)] substance P their duration was reduced to 41.7],
#  [126,
#   ['to', '41.7', '+', '/-', '4.6'],
#   the presence of SP and [Sar(9)Met(O-2)(11)] substance P their duration was reduced to 41.7 +/- 4.6 ms. Low Ca2+ (0.2 mM)-containing artificial cerebrospinal fluid (ACSF) or addition of BaCl2 or CdCl2],
#  [155,
#   ['0.19'],
#   induced speeding of time to sodium current transient peak (Delta time to peak at - 30 mV: 0.19 ms without and 0.37 ms with beta 3 co-expression). Our findings may indicate that in cardiomyocytes],
#  [155,
#   ['and', '0.37'],
#   induced speeding of time to sodium current transient peak (Delta time to peak at - 30 mV: 0.19 ms without and 0.37 ms with beta 3 co-expression). Our findings may indicate that in cardiomyocytes],
#  [155,
#   ['0.19'],
#   to sodium current transient peak (Delta time to peak at - 30 mV: 0.19 ms without and 0.37 ms with beta 3 co-expression). Our findings may indicate that in cardiomyocytes, the interdependence of],
#  [155,
#   ['and', '0.37'],
#   to sodium current transient peak (Delta time to peak at - 30 mV: 0.19 ms without and 0.37 ms with beta 3 co-expression). Our findings may indicate that in cardiomyocytes, the interdependence of],
#  [172,
#   ['0.99', '+', '/-', '0.57'],
#   evoked potentials were successfully obtained in all trials. Mean CMAP latency and negative durations were 0.99 +/- 0.57 ms and 1.49 +/- 0.57 ms, respectively. The median MUNE was 2.06 (IQR 1.88, 3.51],
#  [172,
#   ['and', '1.49', '+', '/-', '0.57'],
#   evoked potentials were successfully obtained in all trials. Mean CMAP latency and negative durations were 0.99 +/- 0.57 ms and 1.49 +/- 0.57 ms, respectively. The median MUNE was 2.06 (IQR 1.88, 3.51],
#  [172,
#   ['0.99', '+', '/-', '0.57'],
#   all trials. Mean CMAP latency and negative durations were 0.99 +/- 0.57 ms and 1.49 +/- 0.57 ms, respectively. The median MUNE was 2.06 (IQR 1.88, 3.51). LAR was induced with],
#  [172,
#   ['and', '1.49', '+', '/-', '0.57'],
#   all trials. Mean CMAP latency and negative durations were 0.99 +/- 0.57 ms and 1.49 +/- 0.57 ms, respectively. The median MUNE was 2.06 (IQR 1.88, 3.51). LAR was induced with],
#  [220,
#   ['-105'],
#   the spinal cord were assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p],
#  [220,
#   ['+', '/-', '13'],
#   the spinal cord were assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p],
#  [220,
#   ['-65'],
#   the spinal cord were assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p],
#  [220,
#   ['+', '/-', '11'],
#   the spinal cord were assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p],
#  [220,
#   ['-105'],
#   assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and],
#  [220,
#   ['+', '/-', '13'],
#   assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and],
#  [220,
#   ['-65'],
#   assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and],
#  [220,
#   ['+', '/-', '11'],
#   assessed using immunohistochemistry. Results: The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and],
#  [220,
#   ['-105'],
#   : The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2],
#  [220,
#   ['+', '/-', '13'],
#   : The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2],
#  [220,
#   ['-65'],
#   : The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2],
#  [220,
#   ['+', '/-', '11'],
#   : The RTX mitigated IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2],
#  [220,
#   ['-105'],
#   IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2) +/- 701],
#  [220,
#   ['+', '/-', '13'],
#   IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2) +/- 701],
#  [220,
#   ['-65'],
#   IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2) +/- 701],
#  [220,
#   ['+', '/-', '11'],
#   IR-induced ARI shortening (-105 ms +/- 13 ms in IR vs. -65 ms +/- 11 ms in IR + RTX, p = 0.028) and DOR augmentation (7093 ms(2) +/- 701],
#  [222,
#   ['100', '-', '199'],
#   -frequency firing. This pattern was associated with an increase in the percentage of interspike intervals 100-199 ms in duration compared with that in C-fibers from control rats and vincristine-treated C-fibers],
#  [227,
#   ['241.8'],
#   in rods, whose depolarizing Phase 3 associated with the light offset also evoked APs of a duration of 241.8 ms and a slope of 4.5 mV/ms. The depolarization speed of Phase 3 (Speed) was],
#  [227,
#   ['241.8'],
#   with the light offset also evoked APs of a duration of 241.8 ms and a slope of 4.5 mV/ms. The depolarization speed of Phase 3 (Speed) was 0.0001-0.0111 mV/ms and 0.103],
#  [284,
#   ['and', '61.2', '+', '/-', '2.0'],
#   sensitive component had a mean time-to-peak and duration of 6.2 +/- 0.3 (SE) ms and 61.2 +/- 2.0 ms, respectively, and an amplitude of similar to 1 mV (n],
#  [284,
#   ['and', '61.2', '+', '/-', '2.0'],
#   -to-peak and duration of 6.2 +/- 0.3 (SE) ms and 61.2 +/- 2.0 ms, respectively, and an amplitude of similar to 1 mV (n = 93). The APS],
#  [284,
#   ['41', '+', '/-', '5'],
#   with respect to the resting potential, had a mean rime-to-peak of 41 +/- 5 ms and duration of 121 +/- 1.1 ms (n = 6), and increased in amplitude with],
#  [284,
#   ['121', '+', '/-', '1.1'],
#   with respect to the resting potential, had a mean rime-to-peak of 41 +/- 5 ms and duration of 121 +/- 1.1 ms (n = 6), and increased in amplitude with],
#  [284,
#   ['41', '+', '/-', '5'],
#   a mean rime-to-peak of 41 +/- 5 ms and duration of 121 +/- 1.1 ms (n = 6), and increased in amplitude with postsynaptic depolarization. 6. Unitary monosynaptic IPSPs],
#  [284,
#   ['121', '+', '/-', '1.1'],
#   a mean rime-to-peak of 41 +/- 5 ms and duration of 121 +/- 1.1 ms (n = 6), and increased in amplitude with postsynaptic depolarization. 6. Unitary monosynaptic IPSPs],
#  [284,
#   ['50'],
#   were equally effective, and it can be estimated that 5-10 CA3 cells must be active within 50 ms to activate a common postsynaptic pyramidal cell. In contrast, discharge in a single interneuron is sufficient to],
#  [287,
#   ['6.8'],
#   of receptive field responses. Some spinal cord cells presented a short-latency, evoked action potential (6.8 ms and a variability of +/-0.5 ms) produced by the RMg stimulation. This is interpreted as a],
#  [287,
#   ['6.8'],
#   cord cells presented a short-latency, evoked action potential (6.8 ms and a variability of +/-0.5 ms) produced by the RMg stimulation. This is interpreted as a direct postsynaptic action of the RMg on],
#  [290,
#   ['10'],
#   accumbens is evoked by electrical stimulation of the fornix/fimbria fibres, with a monosynaptic positive peak at 10 ms (P10). Rats were unilaterally injected with 6-hydroxydopamine in the nucleus accumbens. The contralateral],
#  [296,
#   ['250', '-'],
#   >= 2 Hz. In this state, the peak firing frequency of phasic responses to a 250-ms mechanical stimulus was significantly reduced compared with control. In contrast, the frequency of tonic responses induced by],
#  [296,
#   ['500'],
#   reduced compared with control. In contrast, the frequency of tonic responses induced by mechanical stimuli of >500 ms did not change. In a rare subtype of afferents, which showed conduction velocity speeding during activity,],
#  [302,
#   ['500'],
#   C receptor, to decrease (similar to 25%) the number of action potentials elicited during a 500 ms depolarizing stimulus. Analysis of action potential duration revealed that CNP and cANF significantly decreased 50% repolarization time],
#  [305,
#   ['70'],
#   -diaminopyridine (250-mu-M) though, the Ca2+ current duration decreased from > 70 ms to 8-10 ms as stimulation frequency increased from 0.5 to 20 Hz. Recovery of the duration],
#  [305,
#   ['to', '8', '-', '10'],
#   -diaminopyridine (250-mu-M) though, the Ca2+ current duration decreased from > 70 ms to 8-10 ms as stimulation frequency increased from 0.5 to 20 Hz. Recovery of the duration],
#  [305,
#   ['70'],
#   mu-M) though, the Ca2+ current duration decreased from > 70 ms to 8-10 ms as stimulation frequency increased from 0.5 to 20 Hz. Recovery of the duration following 20-Hz stimulation],
#  [305,
#   ['to', '8', '-', '10'],
#   mu-M) though, the Ca2+ current duration decreased from > 70 ms to 8-10 ms as stimulation frequency increased from 0.5 to 20 Hz. Recovery of the duration following 20-Hz stimulation],
#  [326,
#   ['100'],
#   an action potential following membrane depolarization. However, the duration of the dendritic spike is of the order 100 ms rather than 1 ms, since it involves slow unbinding of glutamate from NMDARs rather than activation of hyperpolarizing],
#  [326,
#   ['1'],
#   an action potential following membrane depolarization. However, the duration of the dendritic spike is of the order 100 ms rather than 1 ms, since it involves slow unbinding of glutamate from NMDARs rather than activation of hyperpolarizing],
#  [326,
#   ['100'],
#   membrane depolarization. However, the duration of the dendritic spike is of the order 100 ms rather than 1 ms, since it involves slow unbinding of glutamate from NMDARs rather than activation of hyperpolarizing K+ channels. It],
#  [326,
#   ['1'],
#   membrane depolarization. However, the duration of the dendritic spike is of the order 100 ms rather than 1 ms, since it involves slow unbinding of glutamate from NMDARs rather than activation of hyperpolarizing K+ channels. It],
#  [333,
#   ['12'],
#   postsynaptic current was nearly linear, whereas the I-V relation of the later excitatory postsynaptic current (12 ms after the peak) was non-linear over the range between -50 and -100 mV. The outward excitatory],
#  [341,
#   ['10.92', '+', '/-', '3.89'],
#   0.17 and 0.81 +/- 0.46, p < 0.001) and the MUAP duration (10.92 +/- 3.89 ms and 14.03 +/- 3.91 ms, p < 0.01) were smaller for the TMR group than for],
#  [341,
#   ['and', '14.03', '+', '/-', '3.91'],
#   0.17 and 0.81 +/- 0.46, p < 0.001) and the MUAP duration (10.92 +/- 3.89 ms and 14.03 +/- 3.91 ms, p < 0.01) were smaller for the TMR group than for],
#  [341,
#   ['10.92', '+', '/-', '3.89'],
#   , p < 0.001) and the MUAP duration (10.92 +/- 3.89 ms and 14.03 +/- 3.91 ms, p < 0.01) were smaller for the TMR group than for the controls. The mean MUAP],
#  [341,
#   ['and', '14.03', '+', '/-', '3.91'],
#   , p < 0.001) and the MUAP duration (10.92 +/- 3.89 ms and 14.03 +/- 3.91 ms, p < 0.01) were smaller for the TMR group than for the controls. The mean MUAP],
#  [344,
#   ['one', '0.1', '-'],
#   mediating electrically evoked responses is proposed here. Electrical stimulation of pontine or medullary reticular formation with one 0.1-ms pulse evokes a short-latency startle-like response. Two pulses were delivered to single sites at],
#  [344,
#   ['0.25', '-', '0.6'],
#   . The results suggest that the startle-evoking substrates have absolute refractory periods that range from 0.25-0.6 ms. When one pulse was delivered to a caudal pontine site and a second pulse was delivered to a],
#  [344,
#   ['+0.4', 'to', '+0.8'],
#   a an ipsilateral medulla site, decreases in required current were observed as interpulse interval increased from +0.4 to +0.8 ms or as interpulse interval decreased from -0.4 to -0.8 ms. These collision-like effects, being symmetric],
#  [344,
#   ['-0.4', 'to', '-0.8'],
#   a an ipsilateral medulla site, decreases in required current were observed as interpulse interval increased from +0.4 to +0.8 ms or as interpulse interval decreased from -0.4 to -0.8 ms. These collision-like effects, being symmetric],
#  [344,
#   ['+0.4', 'to', '+0.8'],
#   were observed as interpulse interval increased from +0.4 to +0.8 ms or as interpulse interval decreased from -0.4 to -0.8 ms. These collision-like effects, being symmetric around an interpulse interval of 0, suggest that electrically],
#  [344,
#   ['-0.4', 'to', '-0.8'],
#   were observed as interpulse interval increased from +0.4 to +0.8 ms or as interpulse interval decreased from -0.4 to -0.8 ms. These collision-like effects, being symmetric around an interpulse interval of 0, suggest that electrically],
#  [344,
#   ['+0.4', 'to', '1.0'],
#   pulse to the ipsilateral medulla, however, required currents decreased sharply as interpulse intervals increased from +0.4 to 1.0 ms and as interpulse intervals decreased from +0.2 to -0.2 ms. These asymmetric collision-like effects suggest that],
#  [344,
#   ['+0.2', 'to', '-0.2'],
#   pulse to the ipsilateral medulla, however, required currents decreased sharply as interpulse intervals increased from +0.4 to 1.0 ms and as interpulse intervals decreased from +0.2 to -0.2 ms. These asymmetric collision-like effects suggest that],
#  [344,
#   ['+0.4', 'to', '1.0'],
#   decreased sharply as interpulse intervals increased from +0.4 to 1.0 ms and as interpulse intervals decreased from +0.2 to -0.2 ms. These asymmetric collision-like effects suggest that strong synapses in the caudal pons, transmitting from pons],
#  [344,
#   ['+0.2', 'to', '-0.2'],
#   decreased sharply as interpulse intervals increased from +0.4 to 1.0 ms and as interpulse intervals decreased from +0.2 to -0.2 ms. These asymmetric collision-like effects suggest that strong synapses in the caudal pons, transmitting from pons],
#  [344,
#   ['0.3', '-'],
#   synapses in the caudal pons, transmitting from pons to medulla, mediate electrically evoked startle. The 0.3-ms asymmetry suggests that the transmission time (i.e., from presynaptic stimulus to postsynaptic action potential) averaged 0.3],
#  [344,
#   ['0.3'],
#   ms asymmetry suggests that the transmission time (i.e., from presynaptic stimulus to postsynaptic action potential) averaged 0.3 ms via monosynaptic connections. The short duration of collision (0.7 ms) suggests that only one postsynaptic action],
#  [344,
#   ['0.7'],
#   ms asymmetry suggests that the transmission time (i.e., from presynaptic stimulus to postsynaptic action potential) averaged 0.3 ms via monosynaptic connections. The short duration of collision (0.7 ms) suggests that only one postsynaptic action],
#  [344,
#   ['0.3'],
#   stimulus to postsynaptic action potential) averaged 0.3 ms via monosynaptic connections. The short duration of collision (0.7 ms) suggests that only one postsynaptic action potential was produced with high probability for each presynaptic action potential.],
#  [344,
#   ['0.7'],
#   stimulus to postsynaptic action potential) averaged 0.3 ms via monosynaptic connections. The short duration of collision (0.7 ms) suggests that only one postsynaptic action potential was produced with high probability for each presynaptic action potential.],
#  [355,
#   ['45'],
#   degrees-C. Results: Capsaicin (10 muM) increased the action potential duration (APD50) from 45 ms to 166 ms. This effect was associated with an inhibition of three distinct K+ currents. The decreasing],
#  [355,
#   ['to', '166'],
#   degrees-C. Results: Capsaicin (10 muM) increased the action potential duration (APD50) from 45 ms to 166 ms. This effect was associated with an inhibition of three distinct K+ currents. The decreasing],
#  [355,
#   ['45'],
#   Results: Capsaicin (10 muM) increased the action potential duration (APD50) from 45 ms to 166 ms. This effect was associated with an inhibition of three distinct K+ currents. The decreasing rank order of],
#  [355,
#   ['to', '166'],
#   Results: Capsaicin (10 muM) increased the action potential duration (APD50) from 45 ms to 166 ms. This effect was associated with an inhibition of three distinct K+ currents. The decreasing rank order of],
#  [355,
#   ['and', '48'],
#   by 10 muM capsaicin. Capsaicin had no effect on the rate of I(TO) recovery from inactivation (tau=49 ms and 48 ms for control and drug respectively). The capsaicin analogue, resiniferatoxin, which as an],
#  [355,
#   ['and', '48'],
#   capsaicin. Capsaicin had no effect on the rate of I(TO) recovery from inactivation (tau=49 ms and 48 ms for control and drug respectively). The capsaicin analogue, resiniferatoxin, which as an irritant is up],
#  [356,
#   ['90'],
#   nerve when the SMU fired with two consecutive inter-spike intervals (ISIs) within the range of 90 ms to 110 ms. Stimuli were delivered with increasing stimulus delays after the preceding SMU action potential (AP],
#  [356,
#   ['to', '110'],
#   nerve when the SMU fired with two consecutive inter-spike intervals (ISIs) within the range of 90 ms to 110 ms. Stimuli were delivered with increasing stimulus delays after the preceding SMU action potential (AP],
#  [356,
#   ['90'],
#   SMU fired with two consecutive inter-spike intervals (ISIs) within the range of 90 ms to 110 ms. Stimuli were delivered with increasing stimulus delays after the preceding SMU action potential (AP), Sham],
#  [356,
#   ['to', '110'],
#   SMU fired with two consecutive inter-spike intervals (ISIs) within the range of 90 ms to 110 ms. Stimuli were delivered with increasing stimulus delays after the preceding SMU action potential (AP), Sham],
#  [363,
#   ['13.16', '+', '/-', '0.64', 'and', '62.26', '+', '/-', '5.35'],
#   +20 MV, tau(i(fast)) and Tau(i(slow)) were 13.16 +/- 0.64 and 62.26 +/- 5.35 ms (n = 34), respectively. In some cells, I(A) inactivation kinetics slowed dramatically after],
#  [368,
#   ['65'],
#   amplitude in all cases. 3. During paired pulse stimulation of the reticulospinal cell body (pulse interval 65 ms) the chemical EPSP component showed a net facilitation in all cases tested [from 0.64 +/- 0.35],
#  [368,
#   ['2.48', '+', '/-', '0.39'],
#   the width of the first and second action potential did not differ [1/2 width (2.48 +/- 0.39 ms and 2.48 +/- 0.42 ms, respectively; n = 8)]. 4. The degree of],
#  [368,
#   ['and', '2.48', '+', '/-', '0.42'],
#   the width of the first and second action potential did not differ [1/2 width (2.48 +/- 0.39 ms and 2.48 +/- 0.42 ms, respectively; n = 8)]. 4. The degree of],
#  [368,
#   ['2.48', '+', '/-', '0.39'],
#   second action potential did not differ [1/2 width (2.48 +/- 0.39 ms and 2.48 +/- 0.42 ms, respectively; n = 8)]. 4. The degree of facilitation varied markedly between different synapses],
#  [368,
#   ['and', '2.48', '+', '/-', '0.42'],
#   second action potential did not differ [1/2 width (2.48 +/- 0.39 ms and 2.48 +/- 0.42 ms, respectively; n = 8)]. 4. The degree of facilitation varied markedly between different synapses],
#  [368,
#   ['1', '-', '2'],
#   amplitude was consistently larger, if the action potential was triggered with a depolarizing current pulse (1-2 ms) applied close to the synapse (0.1-1 mm), than at a longer distance.],
#  [376,
#   ['33', '+', '/-', '9'],
#   20% (MAPD(20)) and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms,],
#  [376,
#   ['and', '110', '+', '/-', '18'],
#   20% (MAPD(20)) and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms,],
#  [376,
#   ['21', '+', '/-', '6'],
#   20% (MAPD(20)) and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms,],
#  [376,
#   ['and', '76', '+', '/-', '13'],
#   20% (MAPD(20)) and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms,],
#  [376,
#   ['33', '+', '/-', '9'],
#   and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and],
#  [376,
#   ['and', '110', '+', '/-', '18'],
#   and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and],
#  [376,
#   ['21', '+', '/-', '6'],
#   and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and],
#  [376,
#   ['and', '76', '+', '/-', '13'],
#   and 90% (MAPD(90)) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and],
#  [376,
#   ['33', '+', '/-', '9'],
#   ) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15],
#  [376,
#   ['and', '110', '+', '/-', '18'],
#   ) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15],
#  [376,
#   ['21', '+', '/-', '6'],
#   ) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15],
#  [376,
#   ['and', '76', '+', '/-', '13'],
#   ) repolarization time (33 +/- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15],
#  [376,
#   ['62', '+', '/-', '12', '/-', '9'],
#   /- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12],
#  [376,
#   ['and', '110', '+', '/-', '18'],
#   /- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12],
#  [376,
#   ['21', '+', '/-', '6'],
#   /- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12],
#  [376,
#   ['and', '76', '+', '/-', '13'],
#   /- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12],
#  [376,
#   ['76', '+', '/-', '15'],
#   /- 9 ms and 110 +/- 18 ms vs 21 +/- 6 ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12],
#  [376,
#   ['and', '76', '+', '/-', '13'],
#   ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of],
#  [376,
#   ['76', '+', '/-', '15'],
#   ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of],
#  [376,
#   ['62', '+', '/-', '12'],
#   ms and 76 +/- 13 ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of],
#  [376,
#   ['76'],
#   ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of ventricular arrhythmia after MI (76],
#  [376,
#   ['76', '+', '/-', '15'],
#   ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of ventricular arrhythmia after MI (76],
#  [376,
#   ['62', '+', '/-', '12'],
#   ms, both P < 0.05) and ERP (76 +/- 15 ms vs 62 +/- 12 ms, P < 0.05), respectively. Carvedilol decreased the inducibility of ventricular arrhythmia after MI (76],
#  [385,
#   ['to', '700'],
#   more depolarised membrane potentials. Subthreshold somatic current injections yielded similar AHPs with a median duration of similar to 700 ms that were not affected by firing of a single action potential. These results indicate that transient deactivation of],
#  [393,
#   ['18.8'],
#   to suppress other types of K+ channels. The time constant of channel inactivation (tau(in)) was 18.8 ms at -70 mV and 6 ms at potentials positive to -20 mV. 3. A fast delayed rectifier (],
#  [393,
#   ['and', '6'],
#   to suppress other types of K+ channels. The time constant of channel inactivation (tau(in)) was 18.8 ms at -70 mV and 6 ms at potentials positive to -20 mV. 3. A fast delayed rectifier (],
#  [393,
#   ['18.8'],
#   channels. The time constant of channel inactivation (tau(in)) was 18.8 ms at -70 mV and 6 ms at potentials positive to -20 mV. 3. A fast delayed rectifier (DR(F)) channel with a],
#  [393,
#   ['and', '6'],
#   channels. The time constant of channel inactivation (tau(in)) was 18.8 ms at -70 mV and 6 ms at potentials positive to -20 mV. 3. A fast delayed rectifier (DR(F)) channel with a],
#  [393,
#   ['1', '-', '3'],
#   activated in a broad potential range between -50 and +60 mV and demonstrated a fast deactivation within 1-3 ms after potential return to -80 mV in high-K-o(+) solution. The tau(in) value],
#  [393,
#   ['90', '-', '150'],
#   to -80 mV in high-K-o(+) solution. The tau(in) value was 90-150 ms at positive membrane potentials. The single-channel current amplitudes were blocked to 55% by 1 mM],
#  [411,
#   ['200'],
#   of either a single stimulus or a train of stimuli delivered at high-frequency (100 Hz, 200 ms). The inhibition of orthodromic PSs produced by high-frequency conditioning stimulation (T-IFS)],
#  [411,
#   ['100', 'and', '800'],
#   Thus, in the presence of tiagabine (20 mu M), orthodromic PSs, evoked 100 and 800 ms following HFS, were inhibited to 7.8 +/-: 2.6% (mean +/- SE) and],
#  [419,
#   ['10.0', '+', '/-', '4.2', 'to', '7.3', '+', '/-', '3.3'],
#   +/- 18.9 MOMEGA (P < 0.01) and from 10.0 +/- 4.2 to 7.3 +/- 3.3 ms (P < 0.05), respectively. During this period, the rheobase (I(rh)) increased],
#  [419,
#   ['2.23', '+', '/-', '0.53', 'to', '1.45', '+', '/-', '0.44'],
#   P < 0.05) in the spike half-width from 2.23 +/- 0.53 to 1.45 +/- 0.44 ms, resulting, in part, from a steepening (P < 0.05) of the slope of the],
#  [419,
#   ['193', '+', '/-', '53'],
#   afterhyperpolarization (mAHP(dur)) decreased (P < 0.05) between 1-2 (193 +/- 53 ms) and 5-6 days (159 +/- 43 ms). Whereas the mAHP(dur) was],
#  [419,
#   ['159', '+', '/-', '43'],
#   afterhyperpolarization (mAHP(dur)) decreased (P < 0.05) between 1-2 (193 +/- 53 ms) and 5-6 days (159 +/- 43 ms). Whereas the mAHP(dur) was],
#  [419,
#   ['193', '+', '/-', '53'],
#   1-2 (193 +/- 53 ms) and 5-6 days (159 +/- 43 ms). Whereas the mAHP(dur) was found to be independent of membrane potential, there was a linear],
#  [419,
#   ['159', '+', '/-', '43'],
#   1-2 (193 +/- 53 ms) and 5-6 days (159 +/- 43 ms). Whereas the mAHP(dur) was found to be independent of membrane potential, there was a linear],
#  [436,
#   ['and', '4'],
#   about 75% of the cells had voltage-dependent inward currents. Action potentials of 60mV amplitude and 4 ms duration, similar to those in embryonic nerve cells in vivo, could be recorded. Three types of],
#  [438,
#   ['100', '-', '500'],
#   events observed in the rat. 4. In cat MNCs, a depolarizing current pulse (100-500 ms; 0.1-0.3 nA) elicited a train of action potentials followed by a prominent after-hyperpolarization],
#  [438,
#   ['100', '-', '200'],
#   K+]o = 6.24 mM), causing a depolarizing 'sag' in the voltage trajectory lasting 100-200 ms which was TTX resistant. The prominent cat HAP and post-train AHP probably activates the opposing sag],
#  [478,
#   ['2', '-', '5'],
#   . Single action potentials in almost one-third of pyramidal cells initiated SPWs at latencies of 2-5 ms with probabilities of 0.07-0.76. Initiating pyramidal cells evoked field IPSPs (fIPSPs) at similar latencies],
#  [481,
#   ['10.5', '+', '/-', '3.7'],
#   amplitude of 2.1 +/- 1.3 mV and a mean width at half-amplitude of 10.5 +/- 3.7 ms (n = 18). Bath application of the N-methyl-D-aspartate (NMDA],
#  [481,
#   ['0.29', '+', '/-', '0.04'],
#   n = 3). Unitary EPSCs mediated by AMPA receptors had fast rise times (0.29 +/- 0.04 ms) and amplitude weighted decay time constants (2 +/- 0.8 ms; n = 16).],
#  [481,
#   ['2', '+', '/-', '0.8'],
#   n = 3). Unitary EPSCs mediated by AMPA receptors had fast rise times (0.29 +/- 0.04 ms) and amplitude weighted decay time constants (2 +/- 0.8 ms; n = 16).],
#  [481,
#   ['0.29', '+', '/-', '0.04'],
#   rise times (0.29 +/- 0.04 ms) and amplitude weighted decay time constants (2 +/- 0.8 ms; n = 16). In the presence of intracellular spermine, these currents showed the characteristic rectifying],
#  [481,
#   ['2', '+', '/-', '0.8'],
#   rise times (0.29 +/- 0.04 ms) and amplitude weighted decay time constants (2 +/- 0.8 ms; n = 16). In the presence of intracellular spermine, these currents showed the characteristic rectifying],
#  [497,
#   ['0.1'],
#   by intracellular application of 4-aminopyridine and tetraethylammonium in frog myelinated axons, a set of brief (0.1 ms) intracellular depolarizing pulses or a long (200 ms) depolarizing pulse evoked a train of action potentials],
#  [497,
#   ['200'],
#   by intracellular application of 4-aminopyridine and tetraethylammonium in frog myelinated axons, a set of brief (0.1 ms) intracellular depolarizing pulses or a long (200 ms) depolarizing pulse evoked a train of action potentials],
#  [497,
#   ['0.1'],
#   frog myelinated axons, a set of brief (0.1 ms) intracellular depolarizing pulses or a long (200 ms) depolarizing pulse evoked a train of action potentials. Under both experimental conditions a hyperpolarizing afterpotential appeared (],
#  [497,
#   ['200'],
#   frog myelinated axons, a set of brief (0.1 ms) intracellular depolarizing pulses or a long (200 ms) depolarizing pulse evoked a train of action potentials. Under both experimental conditions a hyperpolarizing afterpotential appeared (],
#  [497,
#   ['367'],
#   depolarizing pulse evoked a train of action potentials. Under both experimental conditions a hyperpolarizing afterpotential appeared (duration 367 ms +/- 34 mean +/- S.E., n = 15). The purpose of this study was],
#  [534,
#   ['200'],
#   refractory period was prolonged in NF-H -/- and NF-M -/- animals. Intracellular injections of 200 ms depolarizing and hyperpolarizing currents revealed outward and inward rectification in all animal groups. In comparison to control animals],
#  [537,
#   ['10'],
#   a single calyx (giant synapse). 2. A slow NMDA receptor-mediated EPSC peaked in 10 ms and decayed as a double exponential with time constants of 44 and 147 ms. A fast EPSC had],
#  [537,
#   ['44', 'and', '147'],
#   a single calyx (giant synapse). 2. A slow NMDA receptor-mediated EPSC peaked in 10 ms and decayed as a double exponential with time constants of 44 and 147 ms. A fast EPSC had],
#  [537,
#   ['10'],
#   -mediated EPSC peaked in 10 ms and decayed as a double exponential with time constants of 44 and 147 ms. A fast EPSC had a mean rise time of 356 mu s (at 25 degrees C)],
#  [537,
#   ['44', 'and', '147'],
#   -mediated EPSC peaked in 10 ms and decayed as a double exponential with time constants of 44 and 147 ms. A fast EPSC had a mean rise time of 356 mu s (at 25 degrees C)],
#  [537,
#   ['0.70', 'and', '3.43'],
#   degrees C), while the decay was described by a double exponential with time constants of 0.70 and 3.43 ms. 3. Cyclothiazide slowed the decay of the fast EPSC, indicating that it is mediated by AMPA],
#  [543,
#   ['0.92', '+', '/-', '0.04', 'to', '8.1', '+', '/-', '1.1'],
#   ACSF containing TEA, the action potential width was increased from 0.92 +/- 0.04 to 8.1 +/- 1.1 ms in hyperpolarizing DVMs, and from 0.85 +/- 0.01 to 2.4 +/- 1.0 ms in depolarizing DVMs],
#  [543,
#   ['0.85', '+', '/-', '0.01', 'to', '2.4', '+', '/-', '1.0'],
#   ACSF containing TEA, the action potential width was increased from 0.92 +/- 0.04 to 8.1 +/- 1.1 ms in hyperpolarizing DVMs, and from 0.85 +/- 0.01 to 2.4 +/- 1.0 ms in depolarizing DVMs],
#  [543,
#   ['8.1', '+', '/-', '1.1'],
#   8.1 +/- 1.1 ms in hyperpolarizing DVMs, and from 0.85 +/- 0.01 to 2.4 +/- 1.0 ms in depolarizing DVMs. The increase in width was prevented by 2-3 mM-Mn2+.],
#  [543,
#   ['0.85', '+', '/-', '0.01', 'to', '2.4', '+', '/-', '1.0'],
#   8.1 +/- 1.1 ms in hyperpolarizing DVMs, and from 0.85 +/- 0.01 to 2.4 +/- 1.0 ms in depolarizing DVMs. The increase in width was prevented by 2-3 mM-Mn2+.],
#  [549,
#   ['50'],
#   showed a progressive, frequency-dependent spike broadening, reflecting a reduced rate of repolarization. During a 50 ms long 5 spike train, the spike duration increased by 63.6 +/- 3.4% from the Ist to],
#  [550,
#   ['114', '+', '/-', '6'],
#   rats. The heat stimuli generated by a fast solution exchanger had a rise time of 114 +/- 6 ms and a fall time of 146 +/- 13 ms. 2. When heat stimuli were applied to],
#  [550,
#   ['146', '+', '/-', '13'],
#   rats. The heat stimuli generated by a fast solution exchanger had a rise time of 114 +/- 6 ms and a fall time of 146 +/- 13 ms. 2. When heat stimuli were applied to],
#  [550,
#   ['114', '+', '/-', '6'],
#   exchanger had a rise time of 114 +/- 6 ms and a fall time of 146 +/- 13 ms. 2. When heat stimuli were applied to heat-sensitive small (less than or equal to],
#  [550,
#   ['146', '+', '/-', '13'],
#   exchanger had a rise time of 114 +/- 6 ms and a fall time of 146 +/- 13 ms. 2. When heat stimuli were applied to heat-sensitive small (less than or equal to],
#  [550,
#   ['625', '+', '/-', '115'],
#   heat stimulus. The peak of I-heat was reached with a rise time of 625 +/- 115 ms. When the heat stimulus tvas switched off I-heat deactivated with a fall time of 263 +],
#  [550,
#   ['263', '+', '/-', '17'],
#   When the heat stimulus tvas switched off I-heat deactivated with a fall time of 263 +/- 17 ms. 3. During constant heat stimulation I-heat decreased with time constants of 4-5 s],
#  [552,
#   ['70', '-', '210'],
#   . This complex charging could be approximated by two time constants: one in the range of 70-210 ms, the other of <20 ms. 3. Two regions of outward and inward rectification hyperpolarized to],
#  [552,
#   ['20'],
#   . This complex charging could be approximated by two time constants: one in the range of 70-210 ms, the other of <20 ms. 3. Two regions of outward and inward rectification hyperpolarized to],
#  [552,
#   ['70', '-', '210'],
#   by two time constants: one in the range of 70-210 ms, the other of <20 ms. 3. Two regions of outward and inward rectification hyperpolarized to the resting membrane potential were observed,],
#  [552,
#   ['20'],
#   by two time constants: one in the range of 70-210 ms, the other of <20 ms. 3. Two regions of outward and inward rectification hyperpolarized to the resting membrane potential were observed,],
#  [552,
#   ['300', '-', '600'],
#   mM). 5. Activation of an inward or anomalous rectification in these axons was observed 300-600 ms after the start of a current pulse. In addition, a depolarizing afterpotential (DAP) (1],
#  [562,
#   ['100'],
#   could be described by a time-dependent monoexponential function with a time constant-of the order of 100 ms. In contrast, the time course of inactivation was very slow: a +40 mV depolarization relative to],
#  [562,
#   ['10'],
#   to V-r. 4. The outward current activated in a voltage-dependent manner in less than 10 ms with 500 ms depolarizing steps. A kinetic analysis of its decay revealed at least three components, with],
#  [562,
#   ['500'],
#   to V-r. 4. The outward current activated in a voltage-dependent manner in less than 10 ms with 500 ms depolarizing steps. A kinetic analysis of its decay revealed at least three components, with],
#  [562,
#   ['10'],
#   r. 4. The outward current activated in a voltage-dependent manner in less than 10 ms with 500 ms depolarizing steps. A kinetic analysis of its decay revealed at least three components, with the following time],
#  [562,
#   ['500'],
#   r. 4. The outward current activated in a voltage-dependent manner in less than 10 ms with 500 ms depolarizing steps. A kinetic analysis of its decay revealed at least three components, with the following time],
#  [562,
#   ['17'],
#   analysis of its decay revealed at least three components, with the following time constants: a fast (17 ms), a slowly (similar to 150 ms), and a very slowly inactivating component (in],
#  [562,
#   ['to', '150'],
#   analysis of its decay revealed at least three components, with the following time constants: a fast (17 ms), a slowly (similar to 150 ms), and a very slowly inactivating component (in],
#  [562,
#   ['17'],
#   , with the following time constants: a fast (17 ms), a slowly (similar to 150 ms), and a very slowly inactivating component (in the range of seconds). 5. External],
#  [562,
#   ['to', '150'],
#   , with the following time constants: a fast (17 ms), a slowly (similar to 150 ms), and a very slowly inactivating component (in the range of seconds). 5. External],
#  [562,
#   ['24'],
#   (TEA) in the pipette solution. A fast transient ensemble current (mean decay time constant, 24 ms) persisted in the presence of extracellular TEA in 29% of the patches. 6. In summary],
#  [604,
#   ['4.5', '+', '/-', '0.3'],
#   % recovery to basal levels. Action potential duration at 50% repolarization was increased from 4.5 +/- 0.3 ms to 88 +/- 20 ms and resting membrane potential decreased from -55 +/- 2 to -43 +],
#  [604,
#   ['to', '88', '+', '/-', '20'],
#   % recovery to basal levels. Action potential duration at 50% repolarization was increased from 4.5 +/- 0.3 ms to 88 +/- 20 ms and resting membrane potential decreased from -55 +/- 2 to -43 +],
#  [604,
#   ['4.5', '+', '/-', '0.3'],
#   Action potential duration at 50% repolarization was increased from 4.5 +/- 0.3 ms to 88 +/- 20 ms and resting membrane potential decreased from -55 +/- 2 to -43 +/- 4 mV in the presence],
#  [604,
#   ['to', '88', '+', '/-', '20'],
#   Action potential duration at 50% repolarization was increased from 4.5 +/- 0.3 ms to 88 +/- 20 ms and resting membrane potential decreased from -55 +/- 2 to -43 +/- 4 mV in the presence],
#  [607,
#   ['to', '2', '-', '3'],
#   For instance, AP dura-tion ranges from hundreds of microseconds in cerebellar granule cells to 2-3 ms in SNc dopaminergic (DA) neurons. While most of this variation across cell types seems to arise],
#  [615,
#   ['13', '+', '/-', '1'],
#   currents following an active response could be fitted with one fast exponential (time constant = 13 +/- 1 ms, mean +/- SE) and, in 65% of cells, one to three slower time],
#  [615,
#   ['1,500'],
#   slower time course currents (to which exponentials with time constants of similar to 50, 300, or 1,500 ms could be fitted). A very slow late-onset current (detected in 33% of C],
#  [615,
#   ['to', '40'],
#   currents were recorded when membrane potential was hyperpolarized. These currents had mean activation time constants of similar to 40 ms at -120 mV and were Cs+ sensitive and Ba2+ insensitive. 8. The proportion of neurons with],
#  [615,
#   ['and', '800'],
#   had either one or two of three inactivation time constants (means similar to 22, 120, and 800 ms). 9. This study shows that many of the electrical characteristics of isolated dorsal root ganglion neurons],
#  [620,
#   ['0.7', '-', '1.5'],
#   groups based on their spike durations: short-duration neurons with an action potential duration of 0.7-1.5 ms and long-duration neurons with an action potential duration of 1.6-2.9 ms. Choline acetyltransferase immunohistochemistry],
#  [620,
#   ['1.6', '-', '2.9'],
#   groups based on their spike durations: short-duration neurons with an action potential duration of 0.7-1.5 ms and long-duration neurons with an action potential duration of 1.6-2.9 ms. Choline acetyltransferase immunohistochemistry],
#  [620,
#   ['0.7', '-', '1.5'],
#   duration of 0.7-1.5 ms and long-duration neurons with an action potential duration of 1.6-2.9 ms. Choline acetyltransferase immunohistochemistry combined with biocytin labeling indicated that 56% of short-duration neurons and 61],
#  [620,
#   ['1.6', '-', '2.9'],
#   duration of 0.7-1.5 ms and long-duration neurons with an action potential duration of 1.6-2.9 ms. Choline acetyltransferase immunohistochemistry combined with biocytin labeling indicated that 56% of short-duration neurons and 61],
#  [624,
#   ['0.74'],
# ...
#  [1318,
#   ['4.8'],
#   40 mV by 9 +/- 1% at 4.8 ms and by 36 +/- 3% at 350 ms. L-Arginine (270 muM) reduced this current under the same conditions by 9 +/-],
#  [1318,
#   ['350'],
#   40 mV by 9 +/- 1% at 4.8 ms and by 36 +/- 3% at 350 ms. L-Arginine (270 muM) reduced this current under the same conditions by 9 +/-],
#  [1318,
#   ['4.8'],
#   Arginine (270 muM) reduced this current under the same conditions by 9 +/- 1% at 4.8 ms and by 35 +/- 2% at 350 ms. 5 Calcium-activated potassium currents were sensitive],
#  [1318,
#   ['350'],
#   Arginine (270 muM) reduced this current under the same conditions by 9 +/- 1% at 4.8 ms and by 35 +/- 2% at 350 ms. 5 Calcium-activated potassium currents were sensitive],
#  [1318,
#   ['4.8'],
#   same conditions by 9 +/- 1% at 4.8 ms and by 35 +/- 2% at 350 ms. 5 Calcium-activated potassium currents were sensitive to apamin (50 nm), as this reduced],
#  [1318,
#   ['350'],
#   same conditions by 9 +/- 1% at 4.8 ms and by 35 +/- 2% at 350 ms. 5 Calcium-activated potassium currents were sensitive to apamin (50 nm), as this reduced],
#  [1318,
#   ['350'],
#   apamin (50 nm), as this reduced the outward current by 23 +/- 3% at 350 ms when a high calcium-containing pipette was used during a depolarizing command to + 40 MV. L],
#  [1318,
#   ['4.8'],
#   outward current in the presence of apamin (50 nm), by 5 +/- 1% at 4.8 ms and by 19 +/- 2% at 350 ms, indicating that L-arginine could reduce an],
#  [1318,
#   ['350'],
#   outward current in the presence of apamin (50 nm), by 5 +/- 1% at 4.8 ms and by 19 +/- 2% at 350 ms, indicating that L-arginine could reduce an],
#  [1318,
#   ['4.8'],
#   ), by 5 +/- 1% at 4.8 ms and by 19 +/- 2% at 350 ms, indicating that L-arginine could reduce an apamin-insensitive I(k(Ca)). 6 Calcium-],
#  [1318,
#   ['350'],
#   ), by 5 +/- 1% at 4.8 ms and by 19 +/- 2% at 350 ms, indicating that L-arginine could reduce an apamin-insensitive I(k(Ca)). 6 Calcium-],
#  [1318,
#   ['350'],
#   charybdotoxin (10 nm), as this reduced the outward current by 34 +/- 4% at 350 ms when a high calcium-containing pipette was used during a depolarizing command to +40 MV. L-],
#  [1318,
#   ['4.8'],
#   Arginine still decreased the outward current in the presence of charybdotoxin, by 6 +/- 1% at 4.8 ms and 12 +/- 4% at 350 ms, showing that L-arginine could reduce a charybdotoxin],
#  [1318,
#   ['350'],
#   Arginine still decreased the outward current in the presence of charybdotoxin, by 6 +/- 1% at 4.8 ms and 12 +/- 4% at 350 ms, showing that L-arginine could reduce a charybdotoxin],
#  [1318,
#   ['4.8'],
#   of charybdotoxin, by 6 +/- 1% at 4.8 ms and 12 +/- 4% at 350 ms, showing that L-arginine could reduce a charybdotoxin-insensitive I(k(Ca)). 7 The present],
#  [1318,
#   ['350'],
#   of charybdotoxin, by 6 +/- 1% at 4.8 ms and 12 +/- 4% at 350 ms, showing that L-arginine could reduce a charybdotoxin-insensitive I(k(Ca)). 7 The present],
#  [1318,
#   ['4.8'],
#   independent of the action of NO on the calcium channels. The I(k(Ca)) is decreased significantly at 4.8 ms into a depolarizing pulse, at a time that would decrease the rate of repolarization of the action potential],
#  [1318,
#   ['350'],
#   the rate of repolarization of the action potential. I(k(Ca)) is also reduced at longer times (350 ms), indicating an affect on the inactivating process.],
#  [1349,
#   ['100'],
#   ALS1 cases; (iv) in the ALS2 case, each test stimulus applied at the end of 100 ms recovery cycle failed to initiate a second action potential during hypothermia at 20oC; and (v) in],
#  [1357,
#   ['0.2'],
#   . Brief hyperpolarizing conditioning current pulses were delivered, and threshold change at the conditioning-test interval of 0.2 ms was measured as an estimator of the magnitude of persistent Na+ currents. Threshold electrotonus and supernormality were also],
#  [1358,
#   ['2.7', 'to', '1.8'],
#   the final establishment of neuroendocrine relationships. Action potential duration (at half maximum) decreased from 2.7 to 1.8 ms; this was attributable to a decrease in decay time. Application of cadmium (250 mu M)],
#  [1358,
#   ['and', '17.9'],
#   of decay (measured at 0 mV) were 0.29 nS/pF (n = 12) and 17.9 ms (n = 10), respectively. Voltage-dependent properties and density (1.1 nS/pF],
#  [1358,
#   ['2.85', 'to', '1.95'],
#   to mature values, the decay time of the action potentials generated with the model decreased from 2.85 to 1.95 ms. A similar reduction was obtained when only the density of the potassium current was increased. Integration of],
#  [1359,
#   ['and', '7.2', 'and', '15.1'],
#   mean R(N) and T0 measured at V(m) varied between 8.3 and 19.8 MOMEGA, and 7.2 and 15.1 ms, respectively, in the cell classes. 3. Action potentials were overshooting. Their mean duration at],
#  [1359,
#   ['0.25', 'to', '0.73'],
#   classes. 3. Action potentials were overshooting. Their mean duration at half amplitude varied from 0.25 to 0.73 ms among different cell types. Three types of action-potential configurations were distinguished. Type I action potentials],
#  [1363,
#   ['to', '5'],
#   tracings of I-AHP could be modelled as a difference between two exponentials with tau(on) approximate to 5 ms and tau(off) = 50-250 ms. 5. Sympathetic neurones discharged only once at the onset],
#  [1363,
#   ['50', '-', '250'],
#   tracings of I-AHP could be modelled as a difference between two exponentials with tau(on) approximate to 5 ms and tau(off) = 50-250 ms. 5. Sympathetic neurones discharged only once at the onset],
#  [1363,
#   ['to', '5'],
#   as a difference between two exponentials with tau(on) approximate to 5 ms and tau(off) = 50-250 ms. 5. Sympathetic neurones discharged only once at the onset of a long-lasting depolarizing step.],
#  [1363,
#   ['50', '-', '250'],
#   as a difference between two exponentials with tau(on) approximate to 5 ms and tau(off) = 50-250 ms. 5. Sympathetic neurones discharged only once at the onset of a long-lasting depolarizing step.],
#  [1380,
#   ['3.8'],
#   STA exhibited a relatively long latency and a slow time course. The IPSPs began, on average, 3.8 ms after an RFN action potential. The rise times, half-widths and durations of IPSPs were longer],
#  [1394,
#   ['200', '-', '500'],
#   a single action potential of 85-100 mV, followed by an after-hyperpolarization of 200-500 ms. In 10-15% of the neurones, sustained current injection produced repetitive firing at maximal frequency],
#  [1394,
#   ['4.7'],
#   activation increasing at more depolarized potentials. The half-time to peak K+ current amplitude was reduced from 4.7 ms at 0 mV to 3.2 ms at +60 mV. The slow decline of the outward current amplitude during prolonged],
#  [1394,
#   ['to', '3.2'],
#   activation increasing at more depolarized potentials. The half-time to peak K+ current amplitude was reduced from 4.7 ms at 0 mV to 3.2 ms at +60 mV. The slow decline of the outward current amplitude during prolonged],
#  [1394,
#   ['4.7'],
#   . The half-time to peak K+ current amplitude was reduced from 4.7 ms at 0 mV to 3.2 ms at +60 mV. The slow decline of the outward current amplitude during prolonged depolarization followed an exponential time course],
#  [1394,
#   ['to', '3.2'],
#   . The half-time to peak K+ current amplitude was reduced from 4.7 ms at 0 mV to 3.2 ms at +60 mV. The slow decline of the outward current amplitude during prolonged depolarization followed an exponential time course],
#  [1396,
#   ['250'],
#   lasting a few milliseconds and better observed during a train of spikes, and a slow component lasting approximately 250 ms and that comprises the main portion of the AHP. In some cells, a slow (up to],
#  [1402,
#   ['1'],
#   after the major inward currents were blocked with tetrodotoxin. 3. The total outward current activated in <1 ms at voltages above 0 mV. At moderate depolarizations it did not inactivate, but at higher depolarizations an inactivation],
#  [1402,
#   ['to', '260'],
#   At moderate depolarizations it did not inactivate, but at higher depolarizations an inactivation time constant of similar to 260 ms was measured. Some recordings also revealed an additional, slower inactivation time constant of similar to 2.5 s.],
#  [1414,
#   ['90', '-', '100'],
#   with amyotrophic lateral sclerosis had significant increases in depolarizing threshold electrotonus [amyotrophic lateral sclerosis(baseline TEd (90-100 ms)) 49.1 +/- 1.8%; controls(TEd (90-100 ms)) 45.2 +/-],
#  [1414,
#   ['90', '-', '100'],
#   with amyotrophic lateral sclerosis had significant increases in depolarizing threshold electrotonus [amyotrophic lateral sclerosis(baseline TEd (90-100 ms)) 49.1 +/- 1.8%; controls(TEd (90-100 ms)) 45.2 +/-],
#  [1414,
#   ['90', '-', '100'],
#   sclerosis(baseline TEd (90-100 ms)) 49.1 +/- 1.8%; controls(TEd (90-100 ms)) 45.2 +/- 0.6%, P < 0.01] and superexcitability (amyotrophic lateral sclerosis(baseline)],
#  [1414,
#   ['90', '-', '100'],
#   sclerosis(baseline TEd (90-100 ms)) 49.1 +/- 1.8%; controls(TEd (90-100 ms)) 45.2 +/- 0.6%, P < 0.01] and superexcitability (amyotrophic lateral sclerosis(baseline)],
#  [1414,
#   ['2'],
#   ; amyotrophic lateral sclerosis(ON riluzole) 27.3 +/- 2.3%, P < 0.05) and refractoriness at 2 ms (amyotrophic lateral sclerosis(baseline) 98.7 +/- 10.7%; amyotrophic lateral sclerosis(ON riluzole) 67.8 +/-],
#  [1469,
#   ['8.53', '+', '/-', '0.78'],
#   of the late Na+ current were well described by a single exponential whose time constant was 8.53 +/- 0.78 ms (n = 3). Finally, Lqh III slowed the time-course of the remaining peak],
#  [1470,
#   ['hundred'],
#   Most cells displayed spike frequency adaptation (monotonic decline of firing rate to a tonic value) for several hundred milliseconds when depolarized from resting potential, but the cells differed in their response when pre-pulses to other],
#  [1478,
#   ['92', '+', '/-', '8', 'to', '114', '+', '/-', '4'],
#   mV and the deactivation time constant of I(K)fast was prolonged from 92 +/- 8 to 114 +/- 4 ms by 1 mu M fentanyl (p < 0.05, n = 4). These results suggest (],
#  [1479,
#   ['12.9', '+', '/-', '2.2'],
#   mediated inhibitory postsynaptic currents (IPSCs) was prolonged (mean Delta decay time prolongation: 12.9 +/- 2.2 milliseconds; n = 23), and a bicuculline-sensitive tonic current was induced (mean Delta base],
#  [1479,
#   ['3.8', '+', '/-', '2'],
#   ; in the absence of ALLO, however, propofol prolonged the decay time by only 3.8 +/- 2 milliseconds (n = 13). CONCLUSIONS: In cortical neurons, GABA(A) receptor-mediated synaptic transmission],
#  [1490,
#   ['12'],
#   -frequency burst of two or three action potentials and a high-frequency burst, respectively, about 12 ms before the spike component of the spike-and-wave complexes. The frequency of these corresponded to],
#  [1497,
#   ['200'],
#   in free cytoplasmic calcium was seen after each action potential, and decayed with a time constant of about 200 ms in the soma, and 80 ms in the dendrites. At rates higher than 10 Hz, calcium],
#  [1497,
#   ['and', '80'],
#   in free cytoplasmic calcium was seen after each action potential, and decayed with a time constant of about 200 ms in the soma, and 80 ms in the dendrites. At rates higher than 10 Hz, calcium],
#  [1497,
#   ['200'],
#   each action potential, and decayed with a time constant of about 200 ms in the soma, and 80 ms in the dendrites. At rates higher than 10 Hz, calcium transients accumulated as predicted. In addition],
#  [1497,
#   ['and', '80'],
#   each action potential, and decayed with a time constant of about 200 ms in the soma, and 80 ms in the dendrites. At rates higher than 10 Hz, calcium transients accumulated as predicted. In addition],
#  [1497,
#   ['2'],
#   more pronounced at high firing frequency. Spike AHP currents were measured in voltage clamp as tail currents after 2 ms voltage pulses that triggered action currents. Apamin-sensitive AHP (SK) current was measured by subtraction],
#  [1497,
#   ['10', 'and', '15'],
#   by subtraction of tail currents obtained before and after treatment with apamin. SK current peaked between 10 and 15 ms after an action potential, had a decay time constant of about 30 ms, and showed no accumulation],
#  [1497,
#   ['30'],
#   by subtraction of tail currents obtained before and after treatment with apamin. SK current peaked between 10 and 15 ms after an action potential, had a decay time constant of about 30 ms, and showed no accumulation],
#  [1497,
#   ['10', 'and', '15'],
#   current peaked between 10 and 15 ms after an action potential, had a decay time constant of about 30 ms, and showed no accumulation. At frequencies between 5 and 200 spikes s(-1), the maximal SK],
#  [1497,
#   ['30'],
#   current peaked between 10 and 15 ms after an action potential, had a decay time constant of about 30 ms, and showed no accumulation. At frequencies between 5 and 200 spikes s(-1), the maximal SK],
#  [1510,
#   ['and', '1.28', '+', '/-', '0.3'],
#   -old kittens were 15.8 +/- 1.5 M Omega (n = 16) and 1.28 +/- 0.3 ms (n = 16), respectively. Octopus cells fired only a single action potential at the onset],
#  [1535,
#   ['3.35'],
#   ]; P < 0.05) and longer action potential duration (4.61 [4.15-5.85] vs. 3.35 ms [2.12-5.67]; P < 0.05). These findings point to an increased presence of],
#  [1557,
#   ['1', '-', '2'],
#   among neurons in the time course of contralateral inhibition. In some cells the inhibition lasted only 1-2 ms and disappeared rapidly as contralateral lead time was increased. In others, the inhibition lasted as long as],
#  [1557,
#   ['5', '-', '6'],
#   rapidly as contralateral lead time was increased. In others, the inhibition lasted as long as 5-6 ms and disappeared much more gradually. Examples were found of neurons with inhibitory periods that fell between these extremes],
#  [1563,
#   ['5'],
#   activated around -55 to -60 mV from holding potentials negative to resting potential, obtained its peak amplitude within 5 ms and decayed as a single exponential with a time constant of 6-8 ms. Half maximal values],
#  [1563,
#   ['6', '-', '8'],
#   activated around -55 to -60 mV from holding potentials negative to resting potential, obtained its peak amplitude within 5 ms and decayed as a single exponential with a time constant of 6-8 ms. Half maximal values],
#  [1563,
#   ['5'],
#   its peak amplitude within 5 ms and decayed as a single exponential with a time constant of 6-8 ms. Half maximal values for inactivation and activation were -72 and -37 mV, respectively. Bath application of],
#  [1563,
#   ['6', '-', '8'],
#   its peak amplitude within 5 ms and decayed as a single exponential with a time constant of 6-8 ms. Half maximal values for inactivation and activation were -72 and -37 mV, respectively. Bath application of],
#  [1568,
#   ['4', '-', '8'],
#   surface of rat neurohypophysial and hypothalamic regions in situ. In the neurohypophysis, depolarizing pulses of 4-8 ms duration yielded tetrodotoxin (TTX)-sensitive sodium currents, a 4-AP-sensitive 'A'-type potassium current,],
#  [1568,
#   ['0.3', '-', '0.7'],
#   + and Cd2+, identifying them as voltage-gated calcium currents. Depolarizing pulses of 0.3-0.7 ms duration yielded fast biphasic responses, of 1-3 ms duration, composed of mostly sodium and '],
#  [1568,
#   ['1', '-', '3'],
#   + and Cd2+, identifying them as voltage-gated calcium currents. Depolarizing pulses of 0.3-0.7 ms duration yielded fast biphasic responses, of 1-3 ms duration, composed of mostly sodium and '],
#  [1568,
#   ['0.3', '-', '0.7'],
#   calcium currents. Depolarizing pulses of 0.3-0.7 ms duration yielded fast biphasic responses, of 1-3 ms duration, composed of mostly sodium and 'A'-type potassium currents. With high external calcium there were fast],
#  [1568,
#   ['1', '-', '3'],
#   calcium currents. Depolarizing pulses of 0.3-0.7 ms duration yielded fast biphasic responses, of 1-3 ms duration, composed of mostly sodium and 'A'-type potassium currents. With high external calcium there were fast],
#  [1581,
#   ['2.8', '+', '/-', '0.6'],
#   in a mesencephalic slice preparation maintained in vitro. 2. Fast spikes spontaneously fired last 2.8 +/- 0.6 ms (mean +/- S.D.) and have an amplitude of 72.3 +/- 5.3 mV (n =]]

# %%
inf,sup = [],[]

for val in lista_vals:
    if 'and' not in val and 'to' not in val:
        
        if '+' in val and '/-' in val:
            if val[0] != '+':
                # print(val[0],'+/-',val[-1])
                
                if ',' in val[0]:
                    val[0] = val[0].replace(',','.')
                
                if ',' in val[-1]:
                    val[-1] = val[-1].replace(',','.')
                    
                inf.append(round(float(val[0])-float(val[-1]),4))
                sup.append(round(float(val[0])+float(val[-1]),4))
                
                # print(f'inf {float(val[0])-float(val[-1])}')
                # print(f'sup {float(val[0])+float(val[-1])}')
            # print()
            
        # elif '-' in val:
            # print(val)

# %%
print('Contagem de ocorrências',count)
# Out:
# Contagem de ocorrências 366

# %%
word_count = {}
for abs_val in abs_vals:
    #sentence = abs_val[2]
    #print(sentence)

    sentence =[t for t in abs_val[2] if not t.is_stop]
    sentence =[t for t in sentence if not t.is_punct]
    sentence =[t for t in sentence if not t.like_num]

    for word in sentence:
        word = str(word)
        if word not in word_count.keys():
            #print(word_count.keys())
            word_count[word] = 1
        else:
            word_count[word] += 1

# %%
sorted_word_count = {k: v for k, v in sorted(word_count.items(), key=lambda item: item[1])}
list(sorted_word_count.keys())[-50:]
# Out:
# ['firing',
#  'depolarization',
#  'durations',
#  'frequency',
#  'vs',
#  'mV.',
#  'pulses',
#  'slow',
#  'AHP',
#  'spike',
#  'induced',
#  'EPSPs',
#  'rise',
#  'latency',
#  'repolarization',
#  'outward',
#  'evoked',
#  'decay',
#  'currents',
#  'p',
#  'peak',
#  'mean',
#  'cells',
#  'potentials',
#  'vs.',
#  'fast',
#  'respectively',
#  'decreased',
#  'pulse',
#  'reduced',
#  'constant',
#  'IR',
#  'membrane',
#  'P',
#  'AP',
#  'increased',
#  'n',
#  'depolarizing',
#  'amplitude',
#  '<',
#  '=',
#  'neurons',
#  'mV',
#  'action',
#  'current',
#  'potential',
#  'duration',
#  'time',
#  '+',
#  'ms']

# %%
cells_count = {}
for abs_val in abs_vals:
    #sentence = abs_val[2]
    #print(sentence)

    sentence =[t for t in abs_val[2] if not t.is_stop]
    sentence =[t for t in sentence if not t.is_punct]
    sentence =[t for t in sentence if not t.like_num]

    for word in sentence:
        #word = str(word)
        if str(word) == "cells":
            
            cell_type_i = sentence.index(word) - 1
            cell_type = sentence[cell_type_i]

            cell_type = str(cell_type)

            if cell_type not in cells_count.keys():
                #print(word_count.keys())
                cells_count[cell_type] = 1
            else:
                cells_count[cell_type] += 1

# %%
sorted_cells_count = {k: v for k, v in sorted(cells_count.items(), key=lambda item: item[1])}
list(sorted_cells_count.items())[-10:]
# Out:
# [('potential', 1),
#  ('Octopus', 1),
#  ('inhibition', 1),
#  ('s', 2),
#  ('cord', 2),
#  ('pyramidal', 2),
#  ('III', 2),
#  ('basket', 3),
#  ('bistratified', 4),
#  ('spiking', 6)]

# %%
limite = 20
count = 0
lista_mV_vals, abs_mV_vals, abs_ms_mV = [], [], []

#print(abs_vals)
for abs in abs_vals:

    abs_index = abs[0]
    ms_val = abs[1]
    ms_sentence = abs[2]

    #for abs_index, ms_val, ms_sentence in zip(abs[0], abs[1], abs[2]):
        
    print(abs_index)
    abstract= list(df['Abstract'])[abs_index]
    #print(abstract)

    if not isinstance(abstract,float):
        if ' mV ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            mV_indexes = []
            for t in doc:
                if t.text=='mV':
                    mV_indexes.append(t.i)
                    count+=1
                    
            for mV_index in mV_indexes:
                doc_aux = doc[mV_index-20:mV_index+20]
                doc_aux = nlp(str(doc_aux))
                
                #print(doc_aux)
                for t in doc_aux:
                    if t.text=='mV':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_mV_vals.append(vals[::-1])
                            abs_mV_vals.append([abs_index,vals[::-1],doc_aux])
                            abs_ms_mV.append([abs_index, ms_val, vals[::-1]])      
        
        if ' millivolt ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            mV_indexes = []
            for t in doc:
                if t.text=='millivolt':
                    mV_indexes.append(t.i)
                    count+=1
                    
            for mV_index in mV_indexes:
                doc_aux = doc[mV_index-20:mV_index+20]
                doc_aux = nlp(str(doc_aux))
                
                # print(doc_aux)
                for t in doc_aux:
                    if t.text=='millivolt':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_mV_vals.append(vals[::-1])
                            abs_mV_vals.append([abs_mV_index,vals[::-1],doc_aux])
                            abs_ms_mV.append([abs_index, ms_val, vals[::-1]]) 
        
        if ' millivolts ' in abstract:
            
            doc = nlp(abstract)
            # doc = [t for t in doc if not t.is_stop]            
            
            mV_indexes = []
            for t in doc:
                if t.text=='millivolts':
                    mV_indexes.append(t.i)
                    count+=1
                    
            for mV_index in mV_indexes:
                doc_aux = doc[mV_index-20:mV_index+20]
                doc_aux = nlp(str(doc_aux))
                
                # print(doc_aux)
                for t in doc_aux:
                    if t.text=='millivolts':
                        check_index = 1
                        vals = []
                        while True:
                            if doc_aux[t.i-check_index].like_num:
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            elif str(doc_aux[t.i-check_index]) == '/-' or str(doc_aux[t.i-check_index]) == '+' or str(doc_aux[t.i-check_index]) == '-' or str(doc_aux[t.i-check_index]) == 'and' or str(doc_aux[t.i-check_index]) == 'to':
                                vals.append(str(doc_aux[t.i-check_index]))
                                check_index+=1
                            else:
                                break
                        # print(vals[::-1])
                        if len(vals) != 0:
                            lista_mV_vals.append(vals[::-1])
                            abs_mV_vals.append([abs_mV_index,vals[::-1],doc_aux])
                            abs_ms_mV.append([abs_index, ms_val, vals[::-1]])
# Out:
# 10
# 25
# 25
# 28
# 28
# 28
# 28
# 28
# 44
# 44
# 44
# 44
# 44
# 45
# 51
# 53
# 55
# 62
# 62
# 85
# 97
# 97
# 97
# 103
# 108
# 108
# 108
# 108
# 108
# 108
# 113
# 113
# 113
# 114
# 124
# 126
# 126
# 155
# 155
# 155
# 155
# 172
# 172
# 172
# 172
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 222
# 227
# 227
# 284
# 284
# 284
# 284
# 284
# 284
# 284
# 288
# 288
# 291
# 297
# 297
# 303
# 306
# 306
# 306
# 306
# 327
# 327
# 327
# 327
# 334
# 342
# 342
# 342
# 342
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 345
# 356
# 356
# 356
# 356
# 356
# 356
# 357
# 357
# 357
# 357
# 365
# 370
# 370
# 370
# 370
# 370
# 370
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 378
# 387
# 395
# 395
# 395
# 395
# 395
# 395
# 413
# 413
# 421
# 421
# 421
# 421
# 421
# 421
# 438
# 440
# 440
# 480
# 483
# 483
# 483
# 483
# 483
# 499
# 499
# 499
# 499
# 499
# 536
# 539
# 539
# 539
# 539
# 539
# 545
# 545
# 545
# 545
# 551
# 552
# 552
# 552
# 552
# 552
# 552
# 554
# 554
# 554
# 554
# 554
# 564
# 564
# 564
# 564
# 564
# 564
# 564
# 564
# 564
# 564
# 606
# 606
# 606
# 606
# 609
# 617
# 617
# 617
# 617
# 622
# 622
# 622
# 622
# 626
# 626
# 626
# 626
# 626
# 633
# 633
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 650
# 655
# 655
# 655
# 655
# 655
# 669
# 669
# 669
# 669
# 681
# 681
# 681
# 681
# 714
# 714
# 714
# 714
# 714
# 719
# 774
# 774
# 782
# 839
# 839
# 839
# 839
# 926
# 926
# 926
# 926
# 926
# 932
# 942
# 942
# 942
# 942
# 955
# 955
# 955
# 955
# 955
# 955
# 955
# 956
# 956
# 956
# 956
# 989
# 996
# 996
# 1012
# 1012
# 1026
# 1030
# 1030
# 1038
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1051
# 1055
# 1068
# 1074
# 1074
# 1074
# 1074
# 1074
# 1074
# 1074
# 1074
# 1074
# 1075
# 1075
# 1080
# 1089
# 1089
# 1089
# 1089
# 1099
# 1099
# 1099
# 1102
# 1107
# 1107
# 1107
# 1107
# 1107
# 1107
# 1107
# 1107
# 1107
# 1107
# 1122
# 1140
# 1140
# 1140
# 1141
# 1156
# 1167
# 1167
# 1169
# 1169
# 1169
# 1169
# 1169
# 1173
# 1173
# 1173
# 1173
# 1179
# 1179
# 1179
# 1190
# 1190
# 1191
# 1191
# 1191
# 1191
# 1191
# 1191
# 1191
# 1211
# 1275
# 1281
# 1281
# 1281
# 1288
# 1290
# 1295
# 1295
# 1295
# 1295
# 1298
# 1298
# 1298
# 1298
# 1298
# 1298
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1321
# 1321
# 1321
# 1321
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1326
# 1357
# 1365
# 1366
# 1366
# 1366
# 1367
# 1367
# 1371
# 1371
# 1371
# 1371
# 1388
# 1402
# 1402
# 1402
# 1402
# 1402
# 1404
# 1410
# 1410
# 1422
# 1422
# 1422
# 1422
# 1422
# 1478
# 1479
# 1487
# 1488
# 1488
# 1499
# 1506
# 1506
# 1506
# 1506
# 1506
# 1506
# 1506
# 1506
# 1506
# 1519
# 1545
# 1567
# 1567
# 1573
# 1573
# 1573
# 1573
# 1578
# 1578
# 1578
# 1578
# 1578
# 1591

# %%
len(abs_vals),len(abs_mV_vals)
# Out:
# 503

# %%
def is_numeric(string):
    try:
        if string != '-':
            float(string)
            return True
        else:
            return False
    except ValueError:
        return False

razoes,vals_mv,vals_ms = [],[],[]

for val in abs_ms_mV:
    
    for ms_val in val[1]:
        if is_numeric(ms_val):
            break
    
    for mV_val in val[2]:
        if is_numeric(mV_val):
            break
    
    if ',' not in ms_val and ',' not in mV_val and ms_val != '-' and mV_val != '-' and mV_val != '0':
        # razoes.append(float(ms_val)/float(mV_val))
        razoes.append(float(mV_val)/float(ms_val))
        
        # mV_val = np.abs(float(mV_val))
        mV_val = float(mV_val)
        ms_val = float(ms_val)
        
        # if mV_val < 100 and ms_val <= 50 and ms_val >= 5:
        # if mV_val >= -90 and mV_val <= -70 and ms_val <= 50 and ms_val >= 5:
            # vals_mv.append(mV_val)
            # vals_ms.append(ms_val)
        
        vals_mv.append(mV_val)
        vals_ms.append(ms_val)

# %%
plt.scatter(range(len(vals_mv)),vals_mv,label='mv')
plt.scatter(range(len(vals_ms)),vals_ms,label='ms')
# plt.ylim(-10,175)
plt.legend()
plt.tight_layout()

# %%
plt.scatter(np.abs(vals_mv),vals_ms)
plt.ylim(0,2)
plt.show()

# %%
print(pearsonr(vals_mv,vals_ms))
# Out:
# (0.15228557358757397, 1.5189621778910326e-06)

# %%
df = pd.DataFrame({'ms':vals_ms,'mV':vals_mv})

# %%
plt.scatter(df['mV'],df['ms'])

# %%
df.to_csv('ms x mv.csv',index=False)

# %%
plt.hist(razoes,bins=200)
plt.show()
plt.hist(razoes,bins=200)
plt.xlim(-10,10)
plt.show()

# %%
plt.hist(inf,bins=100,density=True, color="purple")
plt.show()
plt.hist(inf,bins=500,density=True, color="purple")
plt.xlim(0,10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 plt.hist(inf,bins=100,density=True, color="purple")
#       2 plt.show()
#       3 plt.hist(inf,bins=500,density=True, color="purple")
#
# NameError: name 'inf' is not defined

# %%
plt.hist(sup,bins=100,density=True, color="purple")
plt.show()
plt.hist(sup,bins=500,density=True, color="purple")
plt.xlim(0,10)
plt.show()

# %%
for abstract in random.sample(list(df['Abstract'].copy()), 3):
    doc = nlp(abstract)
    displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="239ea12d756b4542ad834fbb5a705787-0" class="displacy" width="55700" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Aplysia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">motor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">neurons</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">B1,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">B2,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">B15</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">synthesize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">small</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">cardioactive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">peptides</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">B (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">SCPs).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">previous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">studies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">semi-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">intact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">preparations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">demonstrated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">SCPs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">released</tspan>
#     <tspan class="displacy-tag" dy
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8f10ceeeefef43d29881bdafa7651500-0" class="displacy" width="50275" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Large-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">conductance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Ca2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">+-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">voltage-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">activated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">potassium (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">BKCa)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">channels</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">shape</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">firing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">pattern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">types</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">excitable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">cell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">repolarizing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">K+</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">conductance.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">onset</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">duration</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">the</tspan>
#     <tspan class="displacy-tag
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6fff07f712c044c1b98f0020343ad50d-0" class="displacy" width="39075" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">CA1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">pyramidal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">neurons</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">undergo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">intense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">morphological</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">electrophysiological</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">changes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">second</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">third</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">postnatal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">rats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">throughout</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">period</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">associated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">emergence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">exploratory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">behavior.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">whole</tspan>
#     <tspan class

# %%
for abstract in random.sample(list(df['Abstract'].copy()), 3):
    if not isinstance(abstract,float):
        if ' ms ' in abstract:

            doc = nlp(abstract)

            ms_indexes = []
            for t in doc:
                if t.text=='ms':
                    ms_indexes.append(t.i)
                    count+=1
                    
            for ms_index in ms_indexes:
                doc_aux = doc[ms_index-5:ms_index+5]
                doc_aux = nlp(str(doc_aux))
                displacy.render(doc_aux, style='dep', jupyter=True)

        
        if ' milissecond ' in abstract:

            doc = nlp(abstract)

            ms_indexes = []
            for t in doc:
                if t.text=='ms':
                    ms_indexes.append(t.i)
                    count+=1
                    
            for ms_index in ms_indexes:
                doc_aux = doc[ms_index-5:ms_index+5]
                doc_aux = nlp(str(doc_aux))
                displacy.render(doc_aux, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cca5b5454524400791e80792a996e266-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">little</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">inactivation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">during</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">250</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">ms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">pulses.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">current</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-3" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cca5b5454524400791e80792a996e266-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cca5b5454524400791e80792a996e266-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1440.0,266.5 L1448.0,254.5 1432.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# #### Aula 3 - REGEX: Regular Expressions
